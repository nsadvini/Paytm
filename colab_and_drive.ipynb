# %% [markdown]
# <a href="https://colab.research.google.com/github/nsadvini/Paytm/blob/master/colab_and_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
employee_gen =pd.read_csv('employee_general.csv', delimiter= "|")
employee_rat =pd.read_csv('employee_rating.csv')

# %%
employee_gen
# Out:
#       EmployeeNumber      Education EducationField MaritalStatus
# 0                  1        College  Life Sciences        Single
# 1                  2  Below College  Life Sciences       Married
# 2                  4        College          Other        Single
# 3                  5         Master  Life Sciences       Married
# 4                  7  Below College        Medical       Married
# ...              ...            ...            ...           ...
# 1465            2061        College        Medical       Married
# 1466            2062  Below College        Medical       Married
# 1467            2064       Bachelor  Life Sciences       Married
# 1468            2065       Bachelor        Medical       Married
# 1469            2068       Bachelor        Medical       Married
#
# [1470 rows x 4 columns]

# %%
employee_gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  1470 non-null   int64
#  1   Education       1470 non-null   object
#  2   EducationField  1470 non-null   object
#  3   MaritalStatus   1470 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 46.1+ KB

# %% [markdown]
# Data Types
# 1. Numeric-EmployeeNumber
# 2. Binary- Maritalstatus
# 3. ordinal- Education
# 4. Nominal- EducationField

# %%
employee_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
employee_rat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           1470 non-null   int64
#  1   Department               1470 non-null   object
#  2   EnvironmentSatisfaction  1470 non-null   object
#  3   JobRole                  1470 non-null   object
#  4   PerformanceRating        1470 non-null   object
#  5   YearsAtCompany           1470 non-null   int64
#  6   YearsInCurrentRole       1470 non-null   int64
#  7   MonthlyIncome            1470 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 92.0+ KB

# %% [markdown]
# Data Types
#
# 1. Numeric- EmployeeNumber, YearsAtCompany, YearInCurrentRole, MonthlyIncome.
# 2. Binary- PerformanceRating.
# 3. Nominal- Department, JobRole.
# 4. Ordinal- PerformanceRating, EnvironmentSatisfaction.

# %%
import numpy as np
employee_rat['log_income']=np.log(employee_rat['MonthlyIncome'])
employee_rat[["log_income","MonthlyIncome"]]
# Out:
#       log_income  MonthlyIncome
# 0       8.698347           5993
# 1       8.542861           5130
# 2       7.644919           2090
# 3       7.975565           2909
# 4       8.151333           3468
# ...          ...            ...
# 1465    7.852050           2571
# 1466    9.209440           9991
# 1467    8.722906           6142
# 1468    8.592301           5390
# 1469    8.390268           4404
#
# [1470 rows x 2 columns]

# %%
print(list(set(employee_rat['EnvironmentSatisfaction'])))
print(list(set(employee_rat['PerformanceRating'])))
# Out:
# ['High', 'Low', 'Very High', 'Medium']
# ['Excellent', 'Outstanding']

# %%
Env= {'Low' : 1, 'Medium' : 2, 'High' : 3, 'Very High':4}
perf={'Excellent':1, 'Outstanding':2}

employee_rat['EnvironmentSatisfaction']=employee_rat['EnvironmentSatisfaction'].map(Env)
employee_rat['PerformanceRating']=employee_rat['PerformanceRating'].map(perf)

# %%
employee_rat.head()
# Out:
#    EmployeeNumber              Department  EnvironmentSatisfaction  \
# 0               1                   Sales                        2
# 1               2  Research & Development                        3
# 2               4  Research & Development                        4
# 3               5  Research & Development                        4
# 4               7  Research & Development                        1
#
#                  JobRole  PerformanceRating  YearsAtCompany  \
# 0        Sales Executive                  1               6
# 1     Research Scientist                  2              10
# 2  Laboratory Technician                  1               0
# 3     Research Scientist                  1               8
# 4  Laboratory Technician                  1               2
#
#    YearsInCurrentRole  MonthlyIncome  log_income
# 0                   4           5993    8.698347
# 1                   7           5130    8.542861
# 2                   0           2090    7.644919
# ...

# %%
print(list(set(employee_gen['Education'])))
# Out:
# ['Doctor', 'Master', 'College', 'Bachelor', 'Below College']

# %%
Edu={'Below College':1, 'College':2, 'Bachelor' :3, 'Master':4,'Doctor':4}

employee_gen['Education']= employee_gen['Education'].map(Edu)

# %%
employee_gen.head()
# Out:
#    EmployeeNumber  Education EducationField MaritalStatus
# 0               1          2  Life Sciences        Single
# 1               2          1  Life Sciences       Married
# 2               4          2          Other        Single
# 3               5          4  Life Sciences       Married
# 4               7          1        Medical       Married

# %%
merged = pd.merge(employee_rat, employee_gen, on='EmployeeNumber')
merged.head()
# Out:
#    EmployeeNumber              Department  EnvironmentSatisfaction  \
# 0               1                   Sales                        2
# 1               2  Research & Development                        3
# 2               4  Research & Development                        4
# 3               5  Research & Development                        4
# 4               7  Research & Development                        1
#
#                  JobRole  PerformanceRating  YearsAtCompany  \
# 0        Sales Executive                  1               6
# 1     Research Scientist                  2              10
# 2  Laboratory Technician                  1               0
# 3     Research Scientist                  1               8
# 4  Laboratory Technician                  1               2
#
#    YearsInCurrentRole  MonthlyIncome  log_income  Education EducationField  \
# 0                   4           5993    8.698347          2  Life Sciences
# ...
